# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel (r'PT DS learnerr tracker.xlsx')
df.tail()
# Out:
# C:\Users\happy\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#     Responsible  Priority     Programme        Cohort               Sponsor  \
# 163     Kanyisa       NaN  Data Science  2101PT DS SP        Dimension Data
# 164     Kanyisa       NaN  Data Science  2101PT DS SP        Dimension Data
# 165     Kanyisa       NaN  Data Science  2101PT DS SP        Dimension Data
# 166     Kanyisa       NaN  Data Science  2101PT DS SP       Dimension Data
# 167     Kanyisa       NaN  Data Science  2101PT DS SP  LexisNexis sponsored
#
#                    Name             Surname       Email address  Disabled  \
# 163  UYFZ71161110489485  QHTE42015978323417  BIZP54809593828648       NaN
# 164  RDHH41363913815616  NYWX03056373469070  VLAL75209002924580       NaN
# 165  ZUQW10719786544812  LMNN95967336502614  DNFM27329366767796       NaN
# ...

# %%
# Checking how the dataframe looks like
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 58 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Responsible                                       168 non-null    object
#  1   Priority                                          0 non-null      float64
#  2   Programme                                         168 non-null    object
#  3   Cohort                                            168 non-null    object
#  4   Sponsor                                           168 non-null    object
#  5   Name                                              168 non-null    object
#  6   Surname                                           168 non-null    object
#  7   Email address                                     168 non-null    object
#  8   Disabled                                          0 non-null      float64
# ...

# %%
# i use the describe() function to see the statistic distribution of the entire dataframe
df.describe()
# Out:
#        Priority  Disabled  Explore member who is supporting the Disability?  \
# count       0.0       0.0                                              24.0
# mean        NaN       NaN                                               0.0
# std         NaN       NaN                                               0.0
# min         NaN       NaN                                               0.0
# 25%         NaN       NaN                                               0.0
# 50%         NaN       NaN                                               0.0
# 75%         NaN       NaN                                               0.0
# max         NaN       NaN                                               0.0
#
#        Workbook mark  Project mark  Summative mark  \
# count            0.0           0.0             0.0
# mean             NaN           NaN             NaN
# std              NaN           NaN             NaN
# min              NaN           NaN             NaN
# ...

# %%
# Checking the column names of the entire dataframe
for col in df.columns:
    print(col)
# Out:
# Responsible
# Priority
# Programme
# Cohort
# Sponsor
# Name
# Surname
# Email address
# Disabled
# Disability Support Evidence
# Explore member who is supporting the Disability?
# SIF Completed
# Docs checked
# Docs in order
# Folder created
# SETA registered
# St_1_ID
# St_2_Qual
# St_3_CV
# St_4_Declaration of Authenticity
# st_5_Enrollment Form
# st_6_Learnership Agreement
# st_7_Copy of qualilfication being assessed
# st_8_Assessment guides
# st_9_Appeals procedure
# st_10_Assessment plan
# st_11_Confirmation to be assessed
# st_12_Pre-assessment meeting
# st_13_Assessment policy
# st_14_Assessment instruments
# PoE downloaded from Athena
# PoE checked for Completeness
# PoE Complete
# Coursework completed
# st_15_Assessment tools and answer sheet
# st_18_Logbook
# st_18_Feedback Form
# st_18_Attedance Form
# Submitted for Assessment
# Workbook mark
# Project mark
# Summative mark
# st_16_Assessment feedback form
# Competent / Not Yet Competent
# Assessment review document
# ...

# %%
# delecting the Priority column since its contain null values
del df['Priority']

# %%
# Replacing the NaN values with empty cell in the following columns
df[['Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61','Competent / Not Yet Competent','Disabled','Workbook mark','st_16_Assessment feedback form','Assessment review document','Email re outcome ackowledged','Competent / Not Yet Competent','Docs checked']] = df[['Docs checked','Competent / Not Yet Competent','Email re outcome ackowledged','Assessment review document','st_16_Assessment feedback form','Workbook mark','Disabled','Competent / Not Yet Competent','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 57']].fillna('')

# Replacing the NaN values with 0 valus for this column
df[['Project mark']]=df[['Project mark']].fillna('0')

# %%
del df['Priority']
del df['Summative mark']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 60 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0                                                     397 non-null    object
#  1   Programme                                         390 non-null    object
#  2   Cohort                                            391 non-null    object
#  3   Sponsor                                           391 non-null    object
#  4   Name                                              391 non-null    object
#  5   Surname                                           391 non-null    object
#  6   ID no                                             391 non-null    object
#  7   Email address                                     391 non-null    object
#  8   Disabled                                          402 non-null    object
# ...
