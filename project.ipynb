# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel (r'final (1).xlsx') 
df
# Out:
#      0  Priority              Programme                           Cohort  \
# 0    1       NaN  Intro to Data Science             I2DS Sanlam Feb 2021
# 1    2       NaN  Intro to Data Science           I2DS Std Bank Feb 2021
# 2    3       NaN  Intro to Data Science                   I2DS SAHL 2021
# 3    4       NaN  Intro to Data Science            I2DS Liberty Apr 2021
# 4    5       NaN  Intro to Data Science  I2DS Liberty & Hollard May 2021
# 5    6         1           Data Science            Jan 2021 PT Sponsored
# 6    7       NaN           Data Science                              NaN
# 7    8       NaN           Data Science                              NaN
# 8    9       NaN       Data Engineering                              NaN
# 9   10       NaN       Data Engineering                              NaN
# 10  11       NaN       Data Engineering                              NaN
# 11   0  Priority              Programme                           Cohort
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# 0
# Priority
# Programme
# Cohort
# Start date
# End date
# Sponsors
# # of Students
# Responsible person
# LS / Qual / US
# SETA Registration
# Learnership Registration
# Student Folders Created
# Induction Moderation
# Interval Moderation
# PoE Compilation - Before Exam
# PoE Compilation - Prior to Assessment
# Assessment
# Moderation
# Student Comms
# Verification
# Certification
# SETA Requirements not met

# %%
del df['Priority']
for col in df.columns:
    print(col)
# Out:
# 0
# Programme
# Cohort
# Start date
# End date
# Sponsors
# # of Students
# Responsible person
# LS / Qual / US
# SETA Registration
# Learnership Registration
# Student Folders Created
# Induction Moderation
# Interval Moderation
# PoE Compilation - Before Exam
# PoE Compilation - Prior to Assessment
# Assessment
# Moderation
# Student Comms
# Verification
# Certification
# SETA Requirements not met

# %%
data = df.drop([11], axis=0)
data
# Out:
#      0              Programme                           Cohort   Start date  \
# 0    1  Intro to Data Science             I2DS Sanlam Feb 2021   1-Feb-2021
# 1    2  Intro to Data Science           I2DS Std Bank Feb 2021  28-Feb-2021
# 2    3  Intro to Data Science                   I2DS SAHL 2021  19-Apr-2021
# 3    4  Intro to Data Science            I2DS Liberty Apr 2021  19-Apr-2021
# 4    5  Intro to Data Science  I2DS Liberty & Hollard May 2021  17-May-2021
# 5    6           Data Science            Jan 2021 PT Sponsored  18-Jan-2021
# 6    7           Data Science                              NaN          NaN
# 7    8           Data Science                              NaN          NaN
# 8    9       Data Engineering                              NaN          NaN
# 9   10       Data Engineering                              NaN          NaN
# 10  11       Data Engineering                              NaN          NaN
# ...

# %%
df = df.reset_index()
df
# Out:
#     index   0              Programme                           Cohort  \
# 0       0   1  Intro to Data Science             I2DS Sanlam Feb 2021
# 1       1   2  Intro to Data Science           I2DS Std Bank Feb 2021
# 2       2   3  Intro to Data Science                   I2DS SAHL 2021
# 3       3   4  Intro to Data Science            I2DS Liberty Apr 2021
# 4       4   5  Intro to Data Science  I2DS Liberty & Hollard May 2021
# 5       5   6           Data Science            Jan 2021 PT Sponsored
# 6       6   7           Data Science                              NaN
# 7       7   8           Data Science                              NaN
# 8       8   9       Data Engineering                              NaN
# 9       9  10       Data Engineering                              NaN
# 10     10  11       Data Engineering                              NaN
# 11     11   0              Programme                           Cohort
# ...

# %%
#checkig null spaces in the column
df.isna().any()
# Out:
# index                                    False
# 0                                        False
# Programme                                False
# Cohort                                    True
# Start date                                True
# End date                                  True
# Sponsors                                  True
# # of Students                            False
# Responsible person                       False
# LS / Qual / US                           False
# SETA Registration                        False
# Learnership Registration                 False
# Student Folders Created                  False
# Induction Moderation                     False
# Interval Moderation                      False
# PoE Compilation - Before Exam            False
# PoE Compilation - Prior to Assessment    False
# Assessment                               False
# Moderation                               False
# Student Comms                            False
# ...

# %%
df['Sponsors']
# Out:
# 0                   Sanlam
# 1            Standard Bank
# 2            SA Home Loans
# 3                  Liberty
# 4                      NaN
# 5     Daymon International
# 6           Dimension Data
# 7              Lexis Nexus
# 8                   Cell C
# 9                 Harambee
# 10                 Nedbank
# 11                Sponsors
# 12                  Sanlam
# 13           Standard Bank
# 14           SA Home Loans
# 15                 Liberty
# 16                     NaN
# 17    Daymon International
# 18          Dimension Data
# 19             Lexis Nexus
# 20                  Cell C
# 21                Harambee
# 22                 Nedbank
# Name: Sponsors, dtype: object

# %%
df['End date']
# Out:
# 0     Mar 2021
# 1     Apr 2021
# 2     May 2021
# 3          NaN
# 4          NaN
# 5     Dec 2021
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11    End date
# 12    Mar 2021
# 13    Apr 2021
# 14    May 2021
# 15         NaN
# 16         NaN
# 17    Dec 2021
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# Name: End date, dtype: object
